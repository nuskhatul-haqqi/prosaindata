# %% [markdown]
# # Tugas 4

# %%
# %%capture
pip install networkx

# %%
import networkx as nx
G= nx.Graph()

# %%
G.add_edges_from([(1,2),(1,3),(1,4),(2,3),(3,2),(3,4),(4,5),(4,6),(5,6),(5,7),(5,8),(6,7),(6,8),(7,8),(7,9)])

# %%
nx.draw(G, with_labels=True)

# %% [markdown]
# # Average Distance
# banyaknya node

# %%
DC = nx.degree_centrality(G)
DC
# Out:
# {1: 0.375,
#  2: 0.25,
#  3: 0.375,
#  4: 0.5,
#  5: 0.5,
#  6: 0.5,
#  7: 0.5,
#  8: 0.375,
#  9: 0.125}

# %%
sorted(DC, key=DC.get , reverse=True)
# Out:
# [4, 5, 6, 7, 1, 3, 8, 2, 9]

# %%
type(DC)
# Out:
# dict

# %% [markdown]
# # Closeness centrality
# menghitung banyak lintasan dan menghitung jarak lintasan
# * average distance
# * closeness centrality

# %%
DC = nx.closeness_centrality(G)
DC
# Out:
# {1: 0.47058823529411764,
#  2: 0.34782608695652173,
#  3: 0.47058823529411764,
#  4: 0.6153846153846154,
#  5: 0.6153846153846154,
#  6: 0.6153846153846154,
#  7: 0.5,
#  8: 0.47058823529411764,
#  9: 0.34782608695652173}

# %%
sorted(DC, key=DC.get , reverse=True)
# Out:
# [4, 5, 6, 7, 1, 3, 8, 2, 9]

# %% [markdown]
# # Betweenness Centrality
#
# s = node

# %%
DC = nx.betweenness_centrality(G)
DC
# Out:
# {1: 0.10714285714285714,
#  2: 0.0,
#  3: 0.10714285714285714,
#  4: 0.5357142857142857,
#  5: 0.21428571428571427,
#  6: 0.21428571428571427,
#  7: 0.25,
#  8: 0.0,
#  9: 0.0}

# %%
sorted(DC, key=DC.get , reverse=True)
# Out:
# [4, 7, 5, 6, 1, 3, 2, 8, 9]
